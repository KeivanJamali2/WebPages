# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
from codes.countries import Country
from codes.player import Player

# %%
player1 = Player("Keivan")
# Out:
# [INFO] Getting info about player: Keivan .

# %%
player1.houses
# Out:
# [{'country': 'Iran',
#   'worth': 10000,
#   'number': 1,
#   'occupied': 1,
#   'am_i_there': True}]
