# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from converter import read_excel_with_multiple_tables

# %%
data = read_excel_with_multiple_tables("Daily_for_month.xlsx")
names = list(data.keys())
sheets = [data[name] for name in names]
# Out:
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
# Error processing header for table 3
